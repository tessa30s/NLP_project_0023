# %%
import pandas as pd

comparison = pd.DataFrame({
    "Model": [
        "Naive Bayes",
        "Logistic Regression",
        "SVM",
        "LSTM",
        "GRU",
        "CNN"
    ],

    "Accuracy": [
        0.9659,
        0.9596,
        0.9865,
        0.9900,
        0.9900,
        0.9800
    ],

    "Precision": [
        1.0000,
        0.9787,
        0.9918,
        0.9500,
        0.9500,
        0.9700
    ],

    "Recall": [
        0.7185,
        0.6815,
        0.9918,
        0.9300,
        0.9500,
        0.8900
    ],

    "F1 Score": [
        0.8362,
        0.8035,
        0.9416,
        0.9400,
        0.9500,
        0.9300
    ]
})

comparison
# Out:
#                  Model  Accuracy  Precision  Recall  F1 Score
# 0          Naive Bayes    0.9659     1.0000  0.7185    0.8362
# 1  Logistic Regression    0.9596     0.9787  0.6815    0.8035
# 2                  SVM    0.9865     0.9918  0.9918    0.9416
# 3                 LSTM    0.9900     0.9500  0.9300    0.9400
# 4                  GRU    0.9900     0.9500  0.9500    0.9500
# 5                  CNN    0.9800     0.9700  0.8900    0.9300

# %%
best_model = comparison.loc[comparison["F1 Score"].idxmax()]

print("Best Model")
print(best_model)
# Out:
# Best Model
# Model         GRU
# Accuracy     0.99
# Precision    0.95
# Recall       0.95
# F1 Score     0.95
# Name: 4, dtype: object

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.bar(comparison["Model"], comparison["Accuracy"])
plt.title("Accuracy Comparison of NLP Models")
plt.xlabel("Models")
plt.ylabel("Accuracy")
plt.xticks(rotation=20)
plt.show()

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 loss, accuracy = model.evaluate(X_test, y_test)
#       2 print(accuracy)
#
# NameError: name 'model' is not defined
